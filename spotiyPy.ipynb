# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import datetime

# %%
username="#"
clientId= "#"
clientSecret="#"

# %%
client_credentials_manager = SpotifyClientCredentials(clientId, clientSecret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# dictPlayLists = []
# for i in range(1,100):
#     track_results = sp.search(q='year:'+str(datetime.date.today().year), type='playlist', limit=1,offset=i)
#     tmpDict = None
#     tmpDict = {
#         'idPlayList':track_results['playlists']['items'][0]['id'],
#         'playListName':track_results['playlists']['items'][0]['name']
#     }
#     dictPlayLists.append(tmpDict)

# %%
dictPlayLists
# Out:
# [{'idPlayList': '4ulIuEWGuJiPHXweAIAGNO',
#   'playListName': "TIME's Songs of the Year 2020"},
#  {'idPlayList': '2zNUSUP3nPWnq6TmRtvziy',
#   'playListName': 'Song A Day, For A Year 2020'},
#  {'idPlayList': '4CeyODedBm7b9bObDpkoGw',
#   'playListName': 'Best Songs Of The Year 2020!'},
#  {'idPlayList': '4CeyODedBm7b9bObDpkoGw',
#   'playListName': 'Best Songs Of The Year 2020!'},
#  {'idPlayList': '7cA0yD7YTP11dLtqgYHsaC',
#   'playListName': 'Albums of the Year 2020'},
#  {'idPlayList': '1yDnO5ryYVyZ2FVu4OEzMO',
#   'playListName': 'top songs of the year - 2020'},
#  {'idPlayList': '05hV4NMObBn6VUcxtjXpSD',
#   'playListName': 'Soundtrack to my Year (2020)'},
#  {'idPlayList': '1ogkx1omRVOIjMNWARoNC7',
#   'playListName': 'BBC 6 Music Albums of the Year 2020'},
#  {'idPlayList': '57yOzGxATs2Vmy2O6ObQcw',
#   'playListName': 'Tower of Song of the Year 2020 Nominees'},
#  {'idPlayList': '2JO9ENqDqjZtwd73L4cOdP',
#   'playListName': 'Happy New Year 2020'},
#  {'idPlayList': '5XbWdZenBQKOEpoSLRWswX',
#   'playListName': 'End  of  year 2020 Southern Soul'},
#  {'idPlayList': '2JO9ENqDqjZtwd73L4cOdP',
#   'playListName': 'Happy New Year 2020'},
#  {'idPlayList': '75WlAHvy4sd3x8M5baRtm6',
#   'playListName': 'MOAI End of Year 2020 Party Playlist'},
#  {'idPlayList': '3zFNYIuvWhLPvjzLeHdAXu', 'playListName': 'What a year: 2020'},
#  {'idPlayList': '6GOgql5MVNdDbFXHHrgW4H',
#   'playListName': 'Happy New Year 2020 - By DJ Le Araujo '},
#  {'idPlayList': '75WlAHvy4sd3x8M5baRtm6',
#   'playListName': 'MOAI End of Year 2020 Party Playlist'},
#  {'idPlayList': '6F8JBxdM1hZa1K5bZOyDhk',
#   'playListName': 'Solomun - Worakls - Tale Of Us ◆ Happy New Year 2020 (Electro Junkiee Mix)'},
#  {'idPlayList': '11DOTjuhYlEyYTR1PMeXq9',
#   'playListName': 'Dark Techno Bunker  - Official New Year 2020 Playlist'},
#  {'idPlayList': '3zFNYIuvWhLPvjzLeHdAXu', 'playListName': 'What a year: 2020'},
#  {'idPlayList': '6GOgql5MVNdDbFXHHrgW4H',
#   'playListName': 'Happy New Year 2020 - By DJ Le Araujo '},
#  {'idPlayList': '4PJLpEjlAxP7SV8RTcHTCP',
#   'playListName': 'Tubes Hot Mix Year 2020'},
#  {'idPlayList': '2qwNKbXDczFxqss8DYDTE3',
#   'playListName': 'Liquicity Yearmix 2020'},
#  {'idPlayList': '37i9dQZF1DWVhUYCGnZTnv',
#   'playListName': 'CLASS OF 2020 mixtape'},
#  {'idPlayList': '5TDtuKDbOhrfW7C58XnriZ', 'playListName': 'Pop Hits 2020'},
#  {'idPlayList': '37i9dQZF1DX4OyEPaWHBdk', 'playListName': '2020 MAMA'},
#  {'idPlayList': '3wc6e5ZPCjXAxasjkWlcXc',
#   'playListName': 'New Hindi Songs 2020 (New Bollywood Songs 2020)'},
#  {'idPlayList': '4I4bokQXa1fJBDrthkzzBk',
#   'playListName': 'Pop Christmas 2020'},
#  {'idPlayList': '37i9dQZF1DX01YVP5V6NQJ',
#   'playListName': 'New Year Party Tamil'},
#  {'idPlayList': '37i9dQZF1DWVhUYCGnZTnv',
#   'playListName': 'CLASS OF 2020 mixtape'},
#  {'idPlayList': '5TDtuKDbOhrfW7C58XnriZ', 'playListName': 'Pop Hits 2020'},
#  {'idPlayList': '1aEB7cBvdRwtF8h4ScN3c2', 'playListName': 'BEST OF 2020'},
#  {'idPlayList': '2V7mhhIKXUSDSdek5rYHLb', 'playListName': 'Xmas 2020'},
#  {'idPlayList': '1w9rG1yH4t8JYrE7bC48NH',
#   'playListName': "Today's Hits 2020 - Music Hits Playlist (Top Songs 2020)"},
#  {'idPlayList': '6hiSLVfhavzwk3is3yVXzP',
#   'playListName': 'Sertanejo 2020 Mais Tocadas (Melhores Musicas Sertanejas 2020)'},
#  {'idPlayList': '0NvTo731cP2l4wYwGFzdQ0',
#   'playListName': ' Clean Hits 2020 🍊 Pop Clean Songs 2020 & Non Explicit Hits 2021'},
#  {'idPlayList': '37i9dQZF1DWT0upuUFtT7o',
#   'playListName': 'Fresh Finds: Best of Indie 2020'},
#  {'idPlayList': '1aEB7cBvdRwtF8h4ScN3c2', 'playListName': 'BEST OF 2020'},
#  {'idPlayList': '37i9dQZF1DX7mxcvQfD9BC',
#   'playListName': 'Hot Hits India Presents: Hottest Songs of 2020'},
#  {'idPlayList': '1w9rG1yH4t8JYrE7bC48NH',
#   'playListName': "Today's Hits 2020 - Music Hits Playlist (Top Songs 2020)"},
#  {'idPlayList': '37i9dQZF1DX0TKvggIRJXY',
#   'playListName': 'Top Artists of 2020 Philippines'},
#  {'idPlayList': '0NvTo731cP2l4wYwGFzdQ0',
#   'playListName': ' Clean Hits 2020 🍊 Pop Clean Songs 2020 & Non Explicit Hits 2021'},
#  {'idPlayList': '0Zcj83PRevz0fzZKKZOhta',
#   'playListName': 'TOP 100 Germany Single Charts 2020'},
#  {'idPlayList': '521J2GyREjiFaKEIRkGuIQ',
#   'playListName': 'Kizomba 2020 - As Melhores Kizombas 2020 (Kizomba Novas)'},
#  {'idPlayList': '37i9dQZF1DWWGeEU3DbvDJ',
#   'playListName': '2020 Billboard Music Awards'},
#  {'idPlayList': '37i9dQZF1DWXfIydoEnyUS',
#   'playListName': 'Top Artists of 2020 Australia'},
#  {'idPlayList': '37i9dQZF1DX0TKvggIRJXY',
#   'playListName': 'Top Artists of 2020 Philippines'},
#  {'idPlayList': '3iyY5BxUT4zfCaq0l469HW',
#   'playListName': 'Hit 2020 (Hit List 2020)'},
#  {'idPlayList': '0Zcj83PRevz0fzZKKZOhta',
#   'playListName': 'TOP 100 Germany Single Charts 2020'},
#  {'idPlayList': '1dsaSz83Ra25NpyXQQ3eDB',
#   'playListName': 'New Years Eve 2020!🎉'},
#  {'idPlayList': '37i9dQZF1DWWGeEU3DbvDJ',
#   'playListName': '2020 Billboard Music Awards'},
#  {'idPlayList': '37i9dQZF1DWXfIydoEnyUS',
#   'playListName': 'Top Artists of 2020 Australia'},
#  {'idPlayList': '1IDXcaD3RLEqHl7LHaGV1z',
#   'playListName': 'Playlist Reggaeton 2020 - Mejores Canciones de Reggaeton 2020'},
#  {'idPlayList': '2PylDFPtBFiq2dKO4ibWxv',
#   'playListName': 'Lo Mejor del 2020 - Mejores Canciones en Español'},
#  {'idPlayList': '3UTm82a1PtE5DKzB5NgGY1',
#   'playListName': 'Русские хиты 2020 - новые песни | поп-музык 2020'},
#  {'idPlayList': '6M8bQ27fgqAWR7wZd6PqeK',
#   'playListName': 'BEST HITS 2000-2020 '},
#  {'idPlayList': '37i9dQZF1DX5FZ0gGkvIRf',
#   'playListName': 'Kickass Metal Presents... Best Metal Songs of 2020'},
#  {'idPlayList': '3nir0DqrRB6Ms0B3z2LnFK',
#   'playListName': 'Polski Rap 2020 - Top 50 Najczęściej Słuchana w Grudzień 2020'},
#  {'idPlayList': '1IDXcaD3RLEqHl7LHaGV1z',
#   'playListName': 'Playlist Reggaeton 2020 - Mejores Canciones de Reggaeton 2020'},
#  {'idPlayList': '2PylDFPtBFiq2dKO4ibWxv',
#   'playListName': 'Lo Mejor del 2020 - Mejores Canciones en Español'},
#  {'idPlayList': '3UTm82a1PtE5DKzB5NgGY1',
#   'playListName': 'Русские хиты 2020 - новые песни | поп-музык 2020'},
#  {'idPlayList': '6M8bQ27fgqAWR7wZd6PqeK',
#   'playListName': 'BEST HITS 2000-2020 '},
#  {'idPlayList': '485y8NXP8MkfsgCtoa2Gyd',
#   'playListName': ' Neue Musik 2020 - Aktuelle Hits 2020'},
#  {'idPlayList': '3nir0DqrRB6Ms0B3z2LnFK',
#   'playListName': 'Polski Rap 2020 - Top 50 Najczęściej Słuchana w Grudzień 2020'},
#  {'idPlayList': '747psN7uYtRxqkXZDHDNXE',
#   'playListName': 'Gospel Mais Tocadas 2020 - Playlist Gospel 2020 (Mix As Mais Tocadas)'},
#  {'idPlayList': '2PBRkSzcp21XFR2L99kOMQ',
#   'playListName': 'Reggaeton 2020 - Lo Mejor del Reggaeton (Mejor Musica 2020)'},
#  {'idPlayList': '37i9dQZF1DWT2aDOU7r4aV',
#   'playListName': 'Viva Latino Presents: Best Latin Songs of 2020'},
#  {'idPlayList': '53w0lVHBw0m4eEz54yN8FH', 'playListName': 'Top Hits 2020'},
#  {'idPlayList': '4y7mJB8JLrjhp2c6k3ADGC',
#   'playListName': 'Russische Charts 2020 - TOP 100 Hits in Russia (Топ Чарт 2020)'},
#  {'idPlayList': '34eaogIEYzSONwt2GTAaCE',
#   'playListName': ' Radio Hits 2020 (Radio Music Playlist)'},
#  {'idPlayList': '747psN7uYtRxqkXZDHDNXE',
#   'playListName': 'Gospel Mais Tocadas 2020 - Playlist Gospel 2020 (Mix As Mais Tocadas)'},
#  {'idPlayList': '7J8tAF2T73Fp11duGEyiVP',
#   'playListName': 'Defqon.1 2020 by Q-dance'},
#  {'idPlayList': '6TCuyAtQgdHOtMlqF4Tw4L', 'playListName': 'CMA Awards 2020'},
#  {'idPlayList': '6SI7o431exAuGQVl2ZJQWl',
#   'playListName': '2020 Türkçe Pop Şarkılar (En Iyi Türk Müzik 2020)'},
#  {'idPlayList': '4UfhBYSDU4bgjLPAfzM5JD',
#   'playListName': 'Hits 2020: Mejores Canciones Del Momento (Exitos Verano 2020)'},
#  {'idPlayList': '7EViBaYPuENolxcnL4S2KI',
#   'playListName': 'Polskie Hity 2020 - Muzyka Przeboje 2020 (Nowości Muzyczne)'},
#  {'idPlayList': '37i9dQZF1DX8X0dOzodgNr',
#   'playListName': 'Top Tracks of 2020 Singapore'},
#  {'idPlayList': '1EVE9kOZ2i4171hNdvWVhU',
#   'playListName': 'TOP 100 Songs of 2020 (Best Hit Music Playlist)'},
#  {'idPlayList': '6TCuyAtQgdHOtMlqF4Tw4L', 'playListName': 'CMA Awards 2020'},
#  {'idPlayList': '37i9dQZF1DWWtI4xJVmfFQ',
#   'playListName': 'Top Tracks of 2020 Malaysia'},
#  {'idPlayList': '4UfhBYSDU4bgjLPAfzM5JD',
#   'playListName': 'Hits 2020: Mejores Canciones Del Momento (Exitos Verano 2020)'},
#  {'idPlayList': '7EViBaYPuENolxcnL4S2KI',
#   'playListName': 'Polskie Hity 2020 - Muzyka Przeboje 2020 (Nowości Muzyczne)'},
#  {'idPlayList': '37i9dQZF1DX2ApmO385iVi', 'playListName': '2020 Icons'},
#  {'idPlayList': '2Ryzf9BECIj0fVZJwelmov',
#   'playListName': 'OPM Songs 2020 - OPM Love Songs Tagalog Playlist 2020 (New Filipino Song)'},
#  {'idPlayList': '3LMn3mCxEHJZzCCTkPSY8K',
#   'playListName': 'Musica Movida 2020 - Mejores Canciones Movidas y Divertida 2020'},
#  {'idPlayList': '37i9dQZF1DX4VkeNQew5Ex',
#   'playListName': 'Roots Rising presents...Best Folk & Americana Songs of 2020'},
#  {'idPlayList': '1IuS7ZjqcOWkhjvBBpLQAd',
#   'playListName': '洋楽 2020 - 洋楽 最新 (ようがく2020)'},
#  {'idPlayList': '0la7RHMMbKUbYEUDQLdZ3P',
#   'playListName': 'Musica Pop 2020 (Canciones de Moda 2020)'},
#  {'idPlayList': '1gNRYb7F4meR1QxGADithM',
#   'playListName': 'Top Remixes 2020 ⚡ Best Remixes  2020 HITS ⚡ Summer Remixes Hits 2021 ⚡  Remixes Playlist'},
#  {'idPlayList': '6PYUsr8PT5j8ivYwsyw84k',
#   'playListName': 'Modern Christmas Pop 2020 💕'},
#  {'idPlayList': '4LBmEwlDFBiMApSBwJs4MT',
#   'playListName': 'Muzica Romaneasca 2020 - Cele Mai Ascultate Melodii Pop (Muzica Noua 2020)'},
#  {'idPlayList': '76IHKC783C1yh3gNbtwA7X',
#   'playListName': 'UK Grime Music: Top UK Rap 2020 & UK Hip-Hop 2020 (British Songs)'},
#  {'idPlayList': '37i9dQZF1DWZ2jQBazXjNj',
#   'playListName': 'Los Que Mandan Presents: Best Regional Mexican Songs of 2020'},
#  {'idPlayList': '0la7RHMMbKUbYEUDQLdZ3P',
#   'playListName': 'Musica Pop 2020 (Canciones de Moda 2020)'},
#  {'idPlayList': '37i9dQZF1DX5ENxuuyTX48',
#   'playListName': 'Top Artists of 2020 Malaysia'},
#  {'idPlayList': '4mtMgrj2A4wWoKxBWWSsPS',
#   'playListName': 'The Quietus 2020: Albums of the Year'},
#  {'idPlayList': '4LBmEwlDFBiMApSBwJs4MT',
#   'playListName': 'Muzica Romaneasca 2020 - Cele Mai Ascultate Melodii Pop (Muzica Noua 2020)'},
#  {'idPlayList': '6rI4qO7GCp1lR6Vc8stLdu',
#   'playListName': 'Bandas 2020 - Musicas Nuevas de Banda 2020 (Estrenos)'},
#  {'idPlayList': '2oWrjNsj3RXn7YetZMpgdM',
#   'playListName': 'Defqon.1 Power Hour 2020'},
#  {'idPlayList': '7AxVOIoLmzi4iBO9qUMkKw',
#   'playListName': "The Guardian's top songs of 2020"}]

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs('Top Hits 2020', '53w0lVHBw0m4eEz54yN8FH')

# %%
print(len(ids))
print(ids)
# Out:
# 62
# ['3bbD72wsf4Q0JXQvZSEFQB', '5jnX3H3Lrbqr4Uki72wmkE', '5kvuXlnCyuDmRkZVruzxz4', '1NkaiOsnkhOhFlaW8wiL2g', '1I5rtV3WixTrpPE0RXhlEk', '5mauZuDH2bzEdHBfrL0EPr', '79GffFqS4O7Jj7ndTvLazz', '5W6Aba9D9U3V95ISyEAR3b', '1fICmP1unh0XUHgwstQUk4', '2AeWXl2c0yCkQEojtzJLOD', '1P7LFEf603CkBE74l1MzND', '0jAhiUlB9orWLdyTpFXtRJ', '1zm0zCGdH1LhFNb0ijciuo', '44teJnrlBDT07qw4Aq3kqA', '3JHp3H0eVFqGOUNzlgEz7C', '0q4DsuXFw7s4pJJAeQMYya', '3kEzh2JwIMiYLcZ9qP8Kge', '39b7sAlaMnJg6UK4ZaPbY0', '43svGoLVwCcwzh4ktPfcxV', '31ifj67mced2G3ForAbLCL', '7qQjn0noQXLAsfJNUcfJBc', '5b11thNvajBBqWTuf6vGN8', '7dB2GPQeMEsfNFFOTYD4Y1', '5TyN1i5nO91szkYZCTMUiT', '1DTJNt8NNNGrmwEazjAkNx', '12fEL23WdZgTv3PflL9YzC', '021GjJvPXPUrlLwqbX3vMN', '6Vb6P7CrxHoiNGhPSPjPo7', '0wdJ6oirp6xHmH9lwk8IEY', '2NVBYJpZxm3S4bAEYdaMwf', '52mQFS0ylOvDWtkiwXJYuM', '6l5UQhNUG0k7ggCcvzDLHy', '3JERoo6pokCgQ81z79Jpmo', '3ySAG1l7RQNgrzFMJ4xM7m', '2ZlgqiomIrjvkuWFDSVOLY', '50YpEgpm5ldLYQULTOymTP', '3r9fvtguSpPuZc8ARRwQTJ', '4SSM9KvExeVRZMLvLkK1nn', '4GGSmoTmc5LClrowB4SmEw', '4DX2IMLjPdfg0oh5B6Icxv', '5VsnXmtB618tubQof4dRcB', '3TAH29DxFFiuLdaHOkHA7k', '5Vzpmk27VQ9M77SCkSkERq', '7t8PN5KIiyFL3C5c27IHY0', '7vgv8KZBSo0TPzyIWG9yzV', '3WcGdhN6wvGplwVyixNgfI', '0cAGNiWXRAXX1QKn3Ssbzd', '3mPFEEv3TVp8PQUCPyF1bw', '3d9aUOk1b0muVMSt8eXeiV', '3RDgzyHD6uMNdCVnQIkD32', '6lL4XxFC1AssoWX7pYrxvr', '4vp118aQrJmIQb4Bhn9T3j', '3NLVR0Cjt95Qr8Ap8eKjIE', '7j2jFc1LlQLNPRwbjrgXuv', '4YrS33mjBWWchoLJTkAKwt', '7xn9uXfYkFXfMJgaQxgbCN', '37UkazFa5h6jFQWe4vqVSF', '6B5IJMjjEduRqR2heBEJuT', '79ueb4IxFAEL652kSohQ1z', '4VginDwYTP2eaHJzO0QMjG', '4TnjEaWOeW0eKTKIEvJyCa', '4J4rJEaVpgr2tHwX6Jd13H']

# %%
def getTrackFeatures(id):
    meta = sp.track(id)
    features = sp.audio_features(id)

    # meta²
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    artist_id = meta['album']['artists'][0]['id']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']

    # features

    track = [name, album, artist, artist_id, release_date, length, popularity]
    return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
    time.sleep(.5)
    track = getTrackFeatures(ids[i])
    tracks.append(track)

# %%
# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist','artist_id', 'release_date', 'length', 'popularity'])
df.to_csv("spotify.csv", sep = ',', index=False)

# %%
df = pd.read_csv('spotify.csv')

# %%
samples = df.sample(5)
samples
# Out:
#                                     name  \
# 58  No Good For You (feat. Jaymes Young)
# 27                            White Flag
# 5                                Rollin'
# 55                            Midsection
# 49                        Under The Moon
#
#                                    album      artist               artist_id  \
# 58  No Good For You (feat. Jaymes Young)      Keenan  1xQwlpsU0vjTXIq2kT4ZVT
# 27                            Pigeon Man    Summonte  70slrjM1qHK6WiwJLerxBY
# 5                                Rollin'       Diana  40evB5ihg79VWJAkDjsqd6
# 55                                 BUBBA  KAYTRANADA  6qgnBH6iDM91ipVXv28OMu
# 49                        Under The Moon   070 Shake  12Zk1DFhCbHY6v3xep2ZjI
#
#    release_date  length  popularity
# 58   2019-11-15  204486          41
# 27   2020-11-10  304738          26
# 5    2020-12-04  168000          21
# 55   2019-12-13  289426          50
# 49   2019-12-13  207226          48

# %%
id = list(samples.artist_id)

# %%
id[0]
# Out:
# '6TXM1kV4L8DsDAkAfbOPYk'

# %%
sp.artist_top_tracks(id[0])
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0wXQE5QGxFdviVPa7GKMCA'},
#     'href': 'https://api.spotify.com/v1/albums/0wXQE5QGxFdviVPa7GKMCA',
#     'id': '0wXQE5QGxFdviVPa7GKMCA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27374b0c69ab4942384f1a983bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0274b0c69ab4942384f1a983bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485174b0c69ab4942384f1a983bd',
#       'width': 64}],
#     'name': 'All Night (feat. Ally Brooke)',
#     'release_date': '2020-02-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0wXQE5QGxFdviVPa7GKMCA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#      'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#      'id': '4D75GcNG95ebPtNvoNVXhz',
#      'name': 'Afrojack',
#      'type': 'artist',
#      'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#    'disc_number': 1,
#    'duration_ms': 166413,
#    'explicit': False,
#    'external_ids': {'isrc': 'CYA222000001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0poEFjyV2iHKtxjdWFwjmS'},
#    'href': 'https://api.spotify.com/v1/tracks/0poEFjyV2iHKtxjdWFwjmS',
#    'id': '0poEFjyV2iHKtxjdWFwjmS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'All Night (feat. Ally Brooke)',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a756b4f5e166affa8da90faf4e32180eb0cb8500?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0poEFjyV2iHKtxjdWFwjmS'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TTJxPose5KFhRgHYp1PBm'},
#     'href': 'https://api.spotify.com/v1/albums/6TTJxPose5KFhRgHYp1PBm',
#     'id': '6TTJxPose5KFhRgHYp1PBm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dd28014e8a2c00ff36d8a912',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dd28014e8a2c00ff36d8a912',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dd28014e8a2c00ff36d8a912',
#       'width': 64}],
#     'name': "Baby I'm Coming Home",
#     'release_date': '2020-10-29',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6TTJxPose5KFhRgHYp1PBm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#    'disc_number': 1,
#    'duration_ms': 195692,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P2035371'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HxSczAUouo61zJJIq3Ypl'},
#    'href': 'https://api.spotify.com/v1/tracks/2HxSczAUouo61zJJIq3Ypl',
#    'id': '2HxSczAUouo61zJJIq3Ypl',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Baby I'm Coming Home",
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8de4615acd03b3ea1032faedeeb86ecd4e9232d3?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2HxSczAUouo61zJJIq3Ypl'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#       'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#       'id': '31W5EY0aAly4Qieq6OFu6I',
#       'name': 'A Boogie Wit da Hoodie',
#       'type': 'artist',
#       'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3WsN9dZsEjTvA1bBQF0nZc'},
#     'href': 'https://api.spotify.com/v1/albums/3WsN9dZsEjTvA1bBQF0nZc',
#     'id': '3WsN9dZsEjTvA1bBQF0nZc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d43dbda63c5d07290f2bd43c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d43dbda63c5d07290f2bd43c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d43dbda63c5d07290f2bd43c',
#       'width': 64}],
#     'name': "Lips Don't Lie (feat. A Boogie Wit da Hoodie)",
#     'release_date': '2019-05-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3WsN9dZsEjTvA1bBQF0nZc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#      'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#      'id': '31W5EY0aAly4Qieq6OFu6I',
#      'name': 'A Boogie Wit da Hoodie',
#      'type': 'artist',
#      'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}],
#    'disc_number': 1,
#    'duration_ms': 166762,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21902702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6XemQkX3lgqDC21nNdbdVw'},
#    'href': 'https://api.spotify.com/v1/tracks/6XemQkX3lgqDC21nNdbdVw',
#    'id': '6XemQkX3lgqDC21nNdbdVw',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Lips Don't Lie (feat. A Boogie Wit da Hoodie)",
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c65798e42dd37b9479b4801ccd6b61d6af600045?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6XemQkX3lgqDC21nNdbdVw'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dc6hUwyuIhrZdh80eaCEE'},
#       'href': 'https://api.spotify.com/v1/artists/7dc6hUwyuIhrZdh80eaCEE',
#       'id': '7dc6hUwyuIhrZdh80eaCEE',
#       'name': 'Fedde Le Grand',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dc6hUwyuIhrZdh80eaCEE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7qEf07O8bfCTYzxrUmhkgq'},
#     'href': 'https://api.spotify.com/v1/albums/7qEf07O8bfCTYzxrUmhkgq',
#     'id': '7qEf07O8bfCTYzxrUmhkgq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737ba178c7c811e0d69c3d4f33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027ba178c7c811e0d69c3d4f33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517ba178c7c811e0d69c3d4f33',
#       'width': 64}],
#     'name': 'Gatekeeper',
#     'release_date': '2020-10-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7qEf07O8bfCTYzxrUmhkgq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dc6hUwyuIhrZdh80eaCEE'},
#      'href': 'https://api.spotify.com/v1/artists/7dc6hUwyuIhrZdh80eaCEE',
#      'id': '7dc6hUwyuIhrZdh80eaCEE',
#      'name': 'Fedde Le Grand',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dc6hUwyuIhrZdh80eaCEE'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#    'disc_number': 1,
#    'duration_ms': 150000,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2016001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/02T6r1FheCaKwnJUwNJ04I'},
#    'href': 'https://api.spotify.com/v1/tracks/02T6r1FheCaKwnJUwNJ04I',
#    'id': '02T6r1FheCaKwnJUwNJ04I',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Gatekeeper',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ec0bbcbc8a77bf51b612ba53f6cc6618e3b932c8?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:02T6r1FheCaKwnJUwNJ04I'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4roqYaI40M8uIbDJd69ZHj'},
#     'href': 'https://api.spotify.com/v1/albums/4roqYaI40M8uIbDJd69ZHj',
#     'id': '4roqYaI40M8uIbDJd69ZHj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732022fe2b734f8f98a938eacf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022022fe2b734f8f98a938eacf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512022fe2b734f8f98a938eacf',
#       'width': 64}],
#     'name': 'No Good',
#     'release_date': '2019-11-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4roqYaI40M8uIbDJd69ZHj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#    'disc_number': 1,
#    'duration_ms': 191090,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21906440'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7j2jFc1LlQLNPRwbjrgXuv'},
#    'href': 'https://api.spotify.com/v1/tracks/7j2jFc1LlQLNPRwbjrgXuv',
#    'id': '7j2jFc1LlQLNPRwbjrgXuv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'No Good',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ded1fb6244104e288f262ab3ee253afd1334346b?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7j2jFc1LlQLNPRwbjrgXuv'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Wba3IvT61Jz2kZDVKbrxH'},
#     'href': 'https://api.spotify.com/v1/albums/5Wba3IvT61Jz2kZDVKbrxH',
#     'id': '5Wba3IvT61Jz2kZDVKbrxH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734f89844c76d620ff098ef5c6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024f89844c76d620ff098ef5c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514f89844c76d620ff098ef5c6',
#       'width': 64}],
#     'name': 'Low Key (feat. Tyga)',
#     'release_date': '2019-01-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5Wba3IvT61Jz2kZDVKbrxH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LHRHt1k9lMyONurDHEdrp'},
#      'href': 'https://api.spotify.com/v1/artists/5LHRHt1k9lMyONurDHEdrp',
#      'id': '5LHRHt1k9lMyONurDHEdrp',
#      'name': 'Tyga',
#      'type': 'artist',
#      'uri': 'spotify:artist:5LHRHt1k9lMyONurDHEdrp'}],
#    'disc_number': 1,
#    'duration_ms': 201385,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21900547'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7xhvCzIguRfyfQyGrnWuVn'},
#    'href': 'https://api.spotify.com/v1/tracks/7xhvCzIguRfyfQyGrnWuVn',
#    'id': '7xhvCzIguRfyfQyGrnWuVn',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Low Key (feat. Tyga)',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2da51d14a646b527523e9e3679444727ae0fa4d9?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7xhvCzIguRfyfQyGrnWuVn'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kwEd1P9j15ZqUVP5zK7Pv'},
#       'href': 'https://api.spotify.com/v1/artists/4kwEd1P9j15ZqUVP5zK7Pv',
#       'id': '4kwEd1P9j15ZqUVP5zK7Pv',
#       'name': 'Joe Stone',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kwEd1P9j15ZqUVP5zK7Pv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3zg0RMh7GulXCNQQjC5Ct8'},
#     'href': 'https://api.spotify.com/v1/albums/3zg0RMh7GulXCNQQjC5Ct8',
#     'id': '3zg0RMh7GulXCNQQjC5Ct8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e68695bf4f1b3d3452c173d1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e68695bf4f1b3d3452c173d1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e68695bf4f1b3d3452c173d1',
#       'width': 64}],
#     'name': 'Feeling Dynamite',
#     'release_date': '2020-11-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3zg0RMh7GulXCNQQjC5Ct8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kwEd1P9j15ZqUVP5zK7Pv'},
#      'href': 'https://api.spotify.com/v1/artists/4kwEd1P9j15ZqUVP5zK7Pv',
#      'id': '4kwEd1P9j15ZqUVP5zK7Pv',
#      'name': 'Joe Stone',
#      'type': 'artist',
#      'uri': 'spotify:artist:4kwEd1P9j15ZqUVP5zK7Pv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'}],
#    'disc_number': 1,
#    'duration_ms': 157000,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLZ542001814'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0kw9ZHlFNULgpGGTx2JgH5'},
#    'href': 'https://api.spotify.com/v1/tracks/0kw9ZHlFNULgpGGTx2JgH5',
#    'id': '0kw9ZHlFNULgpGGTx2JgH5',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Feeling Dynamite',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/df07cf6ac52bae2d6213cbe57a8e0a3316985042?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0kw9ZHlFNULgpGGTx2JgH5'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#       'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#       'id': '4D75GcNG95ebPtNvoNVXhz',
#       'name': 'Afrojack',
#       'type': 'artist',
#       'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0AEFcJNs06MlE0vTLSQ1kc'},
#     'href': 'https://api.spotify.com/v1/albums/0AEFcJNs06MlE0vTLSQ1kc',
#     'id': '0AEFcJNs06MlE0vTLSQ1kc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7a095440dbed6b31ae44278',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7a095440dbed6b31ae44278',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7a095440dbed6b31ae44278',
#       'width': 64}],
#     'name': 'What Are We Waiting For?',
#     'release_date': '2020-10-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0AEFcJNs06MlE0vTLSQ1kc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz'},
#      'href': 'https://api.spotify.com/v1/artists/4D75GcNG95ebPtNvoNVXhz',
#      'id': '4D75GcNG95ebPtNvoNVXhz',
#      'name': 'Afrojack',
#      'type': 'artist',
#      'uri': 'spotify:artist:4D75GcNG95ebPtNvoNVXhz'}],
#    'disc_number': 1,
#    'duration_ms': 200276,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P2034732'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Mfl0t1hvP1v6EJL1yIuWf'},
#    'href': 'https://api.spotify.com/v1/tracks/1Mfl0t1hvP1v6EJL1yIuWf',
#    'id': '1Mfl0t1hvP1v6EJL1yIuWf',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'What Are We Waiting For?',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ddf76cecf5323e70c860204d86e340cd7e9125e9?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1Mfl0t1hvP1v6EJL1yIuWf'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YXycRbyyAE0wozTk7QMEq'},
#       'href': 'https://api.spotify.com/v1/artists/4YXycRbyyAE0wozTk7QMEq',
#       'id': '4YXycRbyyAE0wozTk7QMEq',
#       'name': 'Matoma',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YXycRbyyAE0wozTk7QMEq'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5peCrBl7RlaO4qDdxAaBON'},
#     'href': 'https://api.spotify.com/v1/albums/5peCrBl7RlaO4qDdxAaBON',
#     'id': '5peCrBl7RlaO4qDdxAaBON',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27345eb67f17f825346202363ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0245eb67f17f825346202363ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485145eb67f17f825346202363ab',
#       'width': 64}],
#     'name': 'Higher',
#     'release_date': '2019-09-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5peCrBl7RlaO4qDdxAaBON'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YXycRbyyAE0wozTk7QMEq'},
#      'href': 'https://api.spotify.com/v1/artists/4YXycRbyyAE0wozTk7QMEq',
#      'id': '4YXycRbyyAE0wozTk7QMEq',
#      'name': 'Matoma',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YXycRbyyAE0wozTk7QMEq'}],
#    'disc_number': 1,
#    'duration_ms': 195121,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21904805'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7E0UqLtjH5ipLhkX3bCCuK'},
#    'href': 'https://api.spotify.com/v1/tracks/7E0UqLtjH5ipLhkX3bCCuK',
#    'id': '7E0UqLtjH5ipLhkX3bCCuK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Higher',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f2e8a878bc46b3c355781ee5d8fa1a89e4bfdc6b?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7E0UqLtjH5ipLhkX3bCCuK'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#       'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#       'id': '6TXM1kV4L8DsDAkAfbOPYk',
#       'name': 'Ally Brooke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#       'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#       'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#       'name': 'R3HAB',
#       'type': 'artist',
#       'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2VJaUeMCysrmmuVpSzfxPt'},
#     'href': 'https://api.spotify.com/v1/albums/2VJaUeMCysrmmuVpSzfxPt',
#     'id': '2VJaUeMCysrmmuVpSzfxPt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b0a086c81613023ec5d24feb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b0a086c81613023ec5d24feb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b0a086c81613023ec5d24feb',
#       'width': 64}],
#     'name': "Lips Don't Lie (feat. A Boogie Wit da Hoodie) [R3HAB Remix]",
#     'release_date': '2019-07-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2VJaUeMCysrmmuVpSzfxPt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TXM1kV4L8DsDAkAfbOPYk'},
#      'href': 'https://api.spotify.com/v1/artists/6TXM1kV4L8DsDAkAfbOPYk',
#      'id': '6TXM1kV4L8DsDAkAfbOPYk',
#      'name': 'Ally Brooke',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TXM1kV4L8DsDAkAfbOPYk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#      'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#      'id': '31W5EY0aAly4Qieq6OFu6I',
#      'name': 'A Boogie Wit da Hoodie',
#      'type': 'artist',
#      'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#      'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#      'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#      'name': 'R3HAB',
#      'type': 'artist',
#      'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'}],
#    'disc_number': 1,
#    'duration_ms': 183670,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21903865'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5JLDDfDzrRYreGS13X8wec'},
#    'href': 'https://api.spotify.com/v1/tracks/5JLDDfDzrRYreGS13X8wec',
#    'id': '5JLDDfDzrRYreGS13X8wec',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Lips Don't Lie (feat. A Boogie Wit da Hoodie) - R3HAB Remix",
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/32c21cd55ae6a2fe1e1f9030ebc79adf73c8279d?cid=66a487c61a4f49e58fc0cdbf5c301e74',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5JLDDfDzrRYreGS13X8wec'}]}
